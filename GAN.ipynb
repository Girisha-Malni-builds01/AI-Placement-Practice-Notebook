# %% [markdown]
# <a href="https://colab.research.google.com/github/Girisha-Malni-builds01/AI-Placement-Practice-Notebook/blob/Deep-Learning-Basic-Algorithms/GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %%
train_dataset = datasets.CIFAR10(root='./data',\
              train=True, download=True, transform=transform)
dataloader = torch.utils.data.DataLoader(train_dataset, \
                                batch_size=32, shuffle=True)
# Out:
# 100%|██████████| 170M/170M [00:01<00:00, 98.3MB/s]

# %%
latent_dim = 100
lr = 0.0002
beta1 = 0.5
beta2 = 0.999
num_epochs = 10

# %%
class Generator(nn.Module):
    def __init__(self, latent_dim):
        super(Generator, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(latent_dim, 128 * 8 * 8),
            nn.ReLU(),
            nn.Unflatten(1, (128, 8, 8)),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128, momentum=0.78),
            nn.ReLU(),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64, momentum=0.78),
            nn.ReLU(),
            nn.Conv2d(64, 3, kernel_size=3, padding=1),
            nn.Tanh()
        )

    def forward(self, z):
        img = self.model(z)
        return img

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.model = nn.Sequential(
        nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1),
        nn.LeakyReLU(0.2),
        nn.Dropout(0.25),
        nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1),
        nn.ZeroPad2d((0, 1, 0, 1)),
        nn.BatchNorm2d(64, momentum=0.82),
        nn.LeakyReLU(0.25),
        nn.Dropout(0.25),
        nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
        nn.BatchNorm2d(128, momentum=0.82),
        nn.LeakyReLU(0.2),
        nn.Dropout(0.25),
        nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
        nn.BatchNorm2d(256, momentum=0.8),
        nn.LeakyReLU(0.25),
        nn.Dropout(0.25),
        nn.Flatten(),
        nn.Linear(256 * 5 * 5, 1),
        nn.Sigmoid()
    )

    def forward(self, img):
        validity = self.model(img)
        return validity

# %%
generator = Generator(latent_dim).to(device)
discriminator = Discriminator().to(device)

adversarial_loss = nn.BCELoss()

optimizer_G = optim.Adam(generator.parameters()\
                         , lr=lr, betas=(beta1, beta2))
optimizer_D = optim.Adam(discriminator.parameters()\
                         , lr=lr, betas=(beta1, beta2))

# %%
for epoch in range(num_epochs):
    for i, batch in enumerate(dataloader):

        real_images = batch[0].to(device)

        valid = torch.ones(real_images.size(0), 1, device=device)
        fake = torch.zeros(real_images.size(0), 1, device=device)

        real_images = real_images.to(device)

        optimizer_D.zero_grad()

        z = torch.randn(real_images.size(0), latent_dim, device=device)

        fake_images = generator(z)

        real_loss = adversarial_loss(discriminator\
                                     (real_images), valid)
        fake_loss = adversarial_loss(discriminator\
                                     (fake_images.detach()), fake)
        d_loss = (real_loss + fake_loss) / 2

        d_loss.backward()
        optimizer_D.step()

        optimizer_G.zero_grad()

        gen_images = generator(z)

        g_loss = adversarial_loss(discriminator(gen_images), valid)
        g_loss.backward()
        optimizer_G.step()

        if (i + 1) % 100 == 0:
            print(
                f"Epoch [{epoch+1}/{num_epochs}]\
                        Batch {i+1}/{len(dataloader)} "
                f"Discriminator Loss: {d_loss.item():.4f} "
                f"Generator Loss: {g_loss.item():.4f}"
            )
    if (epoch + 1) % 10 == 0:
        with torch.no_grad():
            z = torch.randn(16, latent_dim, device=device)
            generated = generator(z).detach().cpu()
            grid = torchvision.utils.make_grid(generated,\
                                        nrow=4, normalize=True)
            plt.imshow(np.transpose(grid, (1, 2, 0)))
            plt.axis("off")
            plt.show()
# Out:
# Epoch [1/10]                        Batch 100/1563 Discriminator Loss: 0.6018 Generator Loss: 1.4835
# Epoch [1/10]                        Batch 200/1563 Discriminator Loss: 0.4048 Generator Loss: 1.7804
# Epoch [1/10]                        Batch 300/1563 Discriminator Loss: 0.4934 Generator Loss: 1.3945
# Epoch [1/10]                        Batch 400/1563 Discriminator Loss: 0.8322 Generator Loss: 0.8837
# Epoch [1/10]                        Batch 500/1563 Discriminator Loss: 0.9004 Generator Loss: 1.0045
# Epoch [1/10]                        Batch 600/1563 Discriminator Loss: 0.6768 Generator Loss: 0.8803
# Epoch [1/10]                        Batch 700/1563 Discriminator Loss: 0.6589 Generator Loss: 1.0129
# Epoch [1/10]                        Batch 800/1563 Discriminator Loss: 0.5449 Generator Loss: 1.0728
# Epoch [1/10]                        Batch 900/1563 Discriminator Loss: 0.6565 Generator Loss: 1.0605
# Epoch [1/10]                        Batch 1000/1563 Discriminator Loss: 0.5854 Generator Loss: 0.9026
# Epoch [1/10]                        Batch 1100/1563 Discriminator Loss: 0.5186 Generator Loss: 1.3202
# Epoch [1/10]                        Batch 1200/1563 Discriminator Loss: 0.7259 Generator Loss: 1.0067
# Epoch [1/10]                        Batch 1300/1563 Discriminator Loss: 0.5747 Generator Loss: 0.7984
# Epoch [1/10]                        Batch 1400/1563 Discriminator Loss: 0.6285 Generator Loss: 0.9674
# Epoch [1/10]                        Batch 1500/1563 Discriminator Loss: 0.7027 Generator Loss: 1.0082
# Epoch [2/10]                        Batch 100/1563 Discriminator Loss: 0.5345 Generator Loss: 1.0239
# Epoch [2/10]                        Batch 200/1563 Discriminator Loss: 0.8360 Generator Loss: 0.6870
# Epoch [2/10]                        Batch 300/1563 Discriminator Loss: 0.6622 Generator Loss: 0.9897
# Epoch [2/10]                        Batch 400/1563 Discriminator Loss: 0.6577 Generator Loss: 0.8896
# Epoch [2/10]                        Batch 500/1563 Discriminator Loss: 0.6468 Generator Loss: 0.9731
# Epoch [2/10]                        Batch 600/1563 Discriminator Loss: 0.6573 Generator Loss: 1.1905
# Epoch [2/10]                        Batch 700/1563 Discriminator Loss: 0.5298 Generator Loss: 0.8211
# Epoch [2/10]                        Batch 800/1563 Discriminator Loss: 0.7443 Generator Loss: 0.7325
# Epoch [2/10]                        Batch 900/1563 Discriminator Loss: 0.5884 Generator Loss: 0.8043
# Epoch [2/10]                        Batch 1000/1563 Discriminator Loss: 0.9202 Generator Loss: 0.6488
# Epoch [2/10]                        Batch 1100/1563 Discriminator Loss: 0.6046 Generator Loss: 0.9243
# Epoch [2/10]                        Batch 1200/1563 Discriminator Loss: 0.5321 Generator Loss: 1.4363
# Epoch [2/10]                        Batch 1300/1563 Discriminator Loss: 0.5373 Generator Loss: 1.0075
# Epoch [2/10]                        Batch 1400/1563 Discriminator Loss: 0.5841 Generator Loss: 1.4858
# Epoch [2/10]                        Batch 1500/1563 Discriminator Loss: 0.6594 Generator Loss: 1.0490
# Epoch [3/10]                        Batch 100/1563 Discriminator Loss: 0.5743 Generator Loss: 1.3932
# Epoch [3/10]                        Batch 200/1563 Discriminator Loss: 0.4798 Generator Loss: 1.5576
# Epoch [3/10]                        Batch 300/1563 Discriminator Loss: 0.7836 Generator Loss: 0.6817
# Epoch [3/10]                        Batch 400/1563 Discriminator Loss: 0.5104 Generator Loss: 0.9247
# Epoch [3/10]                        Batch 500/1563 Discriminator Loss: 0.4987 Generator Loss: 1.1552
# Epoch [3/10]                        Batch 600/1563 Discriminator Loss: 0.6055 Generator Loss: 1.4332
# Epoch [3/10]                        Batch 700/1563 Discriminator Loss: 0.5562 Generator Loss: 1.1632
# Epoch [3/10]                        Batch 800/1563 Discriminator Loss: 0.5680 Generator Loss: 1.2707
